# %%
import pandas as pd
import json
f = open('review_train.json')
data = json.load(f)
df = pd.DataFrame(data['data'],columns =data['columns'])

# %%
df=df[]

# %%
df2=df[df['stars'].isnull()]

# %%
df[df['user_id']=='-bilc2bsxQWUOjy7SIpYmQ']
# Out:
#                     review_id                 user_id  \
# 15385  Xt1I7_KBAWgiu0_ypJK7yQ  -bilc2bsxQWUOjy7SIpYmQ
# 16854  7Wk-KOBjiuiwSOh2YcALtw  -bilc2bsxQWUOjy7SIpYmQ
# 35357  yLKW4IwRU1vo979U86YptA  -bilc2bsxQWUOjy7SIpYmQ
# 49632  gjqfXgBbpDyAo_msktJqcA  -bilc2bsxQWUOjy7SIpYmQ
# 59321                    None  -bilc2bsxQWUOjy7SIpYmQ
# 59355                    None  -bilc2bsxQWUOjy7SIpYmQ
# 59408                    None  -bilc2bsxQWUOjy7SIpYmQ
# 59534                    None  -bilc2bsxQWUOjy7SIpYmQ
# 59542                    None  -bilc2bsxQWUOjy7SIpYmQ
# 59569                    None  -bilc2bsxQWUOjy7SIpYmQ
# 59662                    None  -bilc2bsxQWUOjy7SIpYmQ
# 59670                    None  -bilc2bsxQWUOjy7SIpYmQ
# 59900                    None  -bilc2bsxQWUOjy7SIpYmQ
# 60030                    None  -bilc2bsxQWUOjy7SIpYmQ
# 60041                    None  -bilc2bsxQWUOjy7SIpYmQ
# 60054                    None  -bilc2bsxQWUOjy7SIpYmQ
# 60101                    None  -bilc2bsxQWUOjy7SIpYmQ
# 60244                    None  -bilc2bsxQWUOjy7SIpYmQ
# 60282                    None  -bilc2bsxQWUOjy7SIpYmQ
# 60360                    None  -bilc2bsxQWUOjy7SIpYmQ
# 60365                    None  -bilc2bsxQWUOjy7SIpYmQ
# 60480                    None  -bilc2bsxQWUOjy7SIpYmQ
#
#                       business_id  stars  useful  funny  cool  \
# 15385  Hj44PIrCtv61ETVclzLMwg_POI    3.0     3.0    1.0   2.0
# 16854  g0lCOgLkkByZrhmwYzP5KA_POI    2.0     5.0    0.0   0.0
# 35357  n0Z10UAJO187H8Zp8gl-rw_POI    3.0     0.0    0.0   0.0
# 49632  54oLdsGU9B8HxFTqCCqV-A_POI    2.0     1.0    0.0   1.0
# 59321  FdoqtMadj4ybDAL7S-yUBQ_POI    NaN     NaN    NaN   NaN
# 59355  8MoqZqlNN9AXzG91_Hpc_Q_POI    NaN     NaN    NaN   NaN
# 59408  tyt3pz0x3ZB8GXsSx1a9Aw_POI    NaN     NaN    NaN   NaN
# 59534  8MoqZqlNN9AXzG91_Hpc_Q_POI    NaN     NaN    NaN   NaN
# 59542  uZYBF0YTU_iKq4_L_PDtMQ_POI    NaN     NaN    NaN   NaN
# 59569  Z0mBsgDzDnFAEC5o4X6G9g_POI    NaN     NaN    NaN   NaN
# 59662  0WrdiQ4qJBu2Gc7wRcIfdw_POI    NaN     NaN    NaN   NaN
# 59670  gYrHa4CckDjgOQc5B-yTKA_POI    NaN     NaN    NaN   NaN
# 59900  NmexnuLm3zyKxsgwbCe7ug_POI    NaN     NaN    NaN   NaN
# 60030  8MoqZqlNN9AXzG91_Hpc_Q_POI    NaN     NaN    NaN   NaN
# 60041  9u79dIXLQzmt9rnOZEnBaQ_POI    NaN     NaN    NaN   NaN
# 60054  tyt3pz0x3ZB8GXsSx1a9Aw_POI    NaN     NaN    NaN   NaN
# 60101  uGo0TCVNOcDQxMArUU0Jrw_POI    NaN     NaN    NaN   NaN
# 60244  kZtl_NJjUnlIQgzFrBhXyQ_POI    NaN     NaN    NaN   NaN
# 60282  WhTRPUduXy3mRBYlmSmsKw_POI    NaN     NaN    NaN   NaN
# 60360  dinxDxiWFUkEpxpIzaGHMQ_POI    NaN     NaN    NaN   NaN
# 60365  6m4A_ciUZn1G302yx1YV1w_POI    NaN     NaN    NaN   NaN
# 60480  w8AxfAjNq7wU5jHmpLSpNg_POI    NaN     NaN    NaN   NaN
#
#                                                     text          date  \
# 15385  Disappointed by my vegetarian sandwich lunch h...  1.447371e+12
# 16854  Disappointing Friday date-night dinner. Servic...  1.442861e+12
# 35357  Summary: Good food; good atmosphere; a little ...  1.387443e+12
# 49632  Skip this place. I have no idea why it was so ...  1.393627e+12
# 59321                             Dog friendly! Love it!  1.325455e+09
# 59355                       Pub Sing March is WONDERFUL!  1.332211e+09
# 59408                                  Bread is amazing!  1.320125e+09
# 59534                   Hard cider on tap - TWO KINDS!!!  1.325026e+09
# 59542  Lovely setting. Seating difficult for elderly ...  1.348021e+09
# 59569  Incredibly great prices, fresh food, comfy spa...  1.386012e+09
# 59662                           Everything is fantastic!  1.349408e+09
# 59670  Fun place but don't try to use the coupons. Th...  1.345951e+09
# 59900  Great to have frozen yogurt in our little neig...  1.393387e+09
# 60030                        TWO hard ciders on tap now!  1.323570e+09
# 60041                           Trying the Turkey burger  1.345596e+09
# 60054  Caprese salad. So good, I had to have it two n...  1.336875e+09
# 60101                          Fashion watching: awesome  1.321736e+09
# 60244                                         Udon time!  1.399860e+09
# 60282                                        Cinnamon!!!  1.342240e+09
# 60360                   Chips not great; salsa fantastic  1.356146e+09
# 60365                                   Lots of friends!  1.400899e+09
# 60480                                  2009 Syrah...YUM!  1.346722e+09
#
#        compliment_count count
# 15385               NaN  None
# 16854               NaN  None
# 35357               NaN  None
# 49632               NaN  None
# 59321               0.0  None
# 59355               0.0  None
# 59408               0.0  None
# 59534               0.0  None
# 59542               0.0  None
# 59569               0.0  None
# 59662               0.0  None
# 59670               0.0  None
# 59900               0.0  None
# 60030               0.0  None
# 60041               0.0  None
# 60054               0.0  None
# 60101               0.0  None
# 60244               0.0  None
# 60282               0.0  None
# 60360               0.0  None
# 60365               0.0  None
# 60480               0.0  None

# %%
df2[df2['user_id']=='-bilc2bsxQWUOjy7SIpYmQ']
# Out:
#       review_id                 user_id                 business_id  stars  \
# 59321      None  -bilc2bsxQWUOjy7SIpYmQ  FdoqtMadj4ybDAL7S-yUBQ_POI    NaN
# 59355      None  -bilc2bsxQWUOjy7SIpYmQ  8MoqZqlNN9AXzG91_Hpc_Q_POI    NaN
# 59408      None  -bilc2bsxQWUOjy7SIpYmQ  tyt3pz0x3ZB8GXsSx1a9Aw_POI    NaN
# 59534      None  -bilc2bsxQWUOjy7SIpYmQ  8MoqZqlNN9AXzG91_Hpc_Q_POI    NaN
# 59542      None  -bilc2bsxQWUOjy7SIpYmQ  uZYBF0YTU_iKq4_L_PDtMQ_POI    NaN
# 59569      None  -bilc2bsxQWUOjy7SIpYmQ  Z0mBsgDzDnFAEC5o4X6G9g_POI    NaN
# 59662      None  -bilc2bsxQWUOjy7SIpYmQ  0WrdiQ4qJBu2Gc7wRcIfdw_POI    NaN
# 59670      None  -bilc2bsxQWUOjy7SIpYmQ  gYrHa4CckDjgOQc5B-yTKA_POI    NaN
# 59900      None  -bilc2bsxQWUOjy7SIpYmQ  NmexnuLm3zyKxsgwbCe7ug_POI    NaN
# 60030      None  -bilc2bsxQWUOjy7SIpYmQ  8MoqZqlNN9AXzG91_Hpc_Q_POI    NaN
# 60041      None  -bilc2bsxQWUOjy7SIpYmQ  9u79dIXLQzmt9rnOZEnBaQ_POI    NaN
# 60054      None  -bilc2bsxQWUOjy7SIpYmQ  tyt3pz0x3ZB8GXsSx1a9Aw_POI    NaN
# 60101      None  -bilc2bsxQWUOjy7SIpYmQ  uGo0TCVNOcDQxMArUU0Jrw_POI    NaN
# 60244      None  -bilc2bsxQWUOjy7SIpYmQ  kZtl_NJjUnlIQgzFrBhXyQ_POI    NaN
# 60282      None  -bilc2bsxQWUOjy7SIpYmQ  WhTRPUduXy3mRBYlmSmsKw_POI    NaN
# 60360      None  -bilc2bsxQWUOjy7SIpYmQ  dinxDxiWFUkEpxpIzaGHMQ_POI    NaN
# 60365      None  -bilc2bsxQWUOjy7SIpYmQ  6m4A_ciUZn1G302yx1YV1w_POI    NaN
# 60480      None  -bilc2bsxQWUOjy7SIpYmQ  w8AxfAjNq7wU5jHmpLSpNg_POI    NaN
#
#        useful  funny  cool                                               text  \
# 59321     NaN    NaN   NaN                             Dog friendly! Love it!
# 59355     NaN    NaN   NaN                       Pub Sing March is WONDERFUL!
# 59408     NaN    NaN   NaN                                  Bread is amazing!
# 59534     NaN    NaN   NaN                   Hard cider on tap - TWO KINDS!!!
# 59542     NaN    NaN   NaN  Lovely setting. Seating difficult for elderly ...
# 59569     NaN    NaN   NaN  Incredibly great prices, fresh food, comfy spa...
# 59662     NaN    NaN   NaN                           Everything is fantastic!
# 59670     NaN    NaN   NaN  Fun place but don't try to use the coupons. Th...
# 59900     NaN    NaN   NaN  Great to have frozen yogurt in our little neig...
# 60030     NaN    NaN   NaN                        TWO hard ciders on tap now!
# 60041     NaN    NaN   NaN                           Trying the Turkey burger
# 60054     NaN    NaN   NaN  Caprese salad. So good, I had to have it two n...
# 60101     NaN    NaN   NaN                          Fashion watching: awesome
# 60244     NaN    NaN   NaN                                         Udon time!
# 60282     NaN    NaN   NaN                                        Cinnamon!!!
# 60360     NaN    NaN   NaN                   Chips not great; salsa fantastic
# 60365     NaN    NaN   NaN                                   Lots of friends!
# 60480     NaN    NaN   NaN                                  2009 Syrah...YUM!
#
#                date  compliment_count count
# 59321  1.325455e+09               0.0  None
# 59355  1.332211e+09               0.0  None
# 59408  1.320125e+09               0.0  None
# 59534  1.325026e+09               0.0  None
# 59542  1.348021e+09               0.0  None
# 59569  1.386012e+09               0.0  None
# 59662  1.349408e+09               0.0  None
# 59670  1.345951e+09               0.0  None
# 59900  1.393387e+09               0.0  None
# 60030  1.323570e+09               0.0  None
# 60041  1.345596e+09               0.0  None
# 60054  1.336875e+09               0.0  None
# 60101  1.321736e+09               0.0  None
# 60244  1.399860e+09               0.0  None
# 60282  1.342240e+09               0.0  None
# 60360  1.356146e+09               0.0  None
# 60365  1.400899e+09               0.0  None
# 60480  1.346722e+09               0.0  None

# %%
import os

# Print the current working directory
print("Current working directory: {0}".format(os.getcwd()))

# Change the current working directory
os.chdir('D:/')
# Out:
# Current working directory: C:\Users\Lenovo\Desktop

# %%
from transformers import AutoModelForSequenceClassification, AutoTokenizer
model = AutoModelForSequenceClassification.from_pretrained("nihaldsouza1/yelp-rating-classification")

tokenizer = AutoTokenizer.from_pretrained("nihaldsouza1/yelp-rating-classification")

# %%
from tqdm import tqdm
import torch
res=list(df['text'].values)

star=[]

for i in tqdm(range(len(res))):
    inputs=res[i]
    inputs = tokenizer(inputs, return_tensors="pt")
    k=torch.argmax(model(**inputs).logits[0]).item()+1
    star.append(k)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 11992/11992 [03:16<00:00, 61.17it/s]

# %%
df['star']=star
# Out:
# <ipython-input-11-d53dcc042fdb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['star']=star

# %%
df['new_star']=star
# Out:
# <ipython-input-12-ee598fcbbaac>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['new_star']=star

# %%
df.to_csv('res2.csv')

# %%
os.getcwd()
# Out:
# 'D:\\'

# %%
df3=df[df['stars'].isnull()]

# %%
df3=df3.copy()

# %%
df3['stars']=star

# %%
df3.to_csv('res3.csv')

# %%
df3[]
# Out:
#       review_id                 user_id                 business_id  stars  \
# 49699      None  j2sEA3hiUcwHfq9Ml6M47g  EXYbKA1tocvOK_1tXxZXLA_POI      1
# 49700      None  nZB33t0RFtq_jTxJJJ6wfA  RNzhLU8zy1L5dBkjRK4xEA_POI      5
# 49701      None  9qZVikoJoqfQK9SBSynAGA  l-rGtJt0E7PAklT0IK7oFQ_POI      5
# 49702      None  QVoOwjH06W-jYMjVh8hwIQ  SAQgO7Ij2cdnMp8VQKBffA_POI      4
# 49703      None  IgmfJOA9yFyTr8B2BWcVqA  QLHgjBHBoeIUoEvIPvjHnw_POI      1
# ...         ...                     ...                         ...    ...
# 61686      None  8YsUWA4gkTbja323XoRXUg  YgbIbmfDlB-bZSsjuIfKwA_POI      4
# 61687      None  SGwt_hJqKn46rOSr6VjBpA  PZIVcSuN-G_I6oG6EVKntQ_POI      4
# 61688      None  IFxCdobQsw6Mvwi5PyD6Ow  54oLdsGU9B8HxFTqCCqV-A_POI      1
# 61689      None  ydIdyGQyO8eZe0yqgs0DfA  vh229jJXjCCdO-b4K-JIIw_POI      1
# 61690      None  ydIdyGQyO8eZe0yqgs0DfA  34Eqv8jXgxg_EEwcsNgeeg_POI      2
#
#        useful  funny  cool                                               text  \
# 49699     NaN    NaN   NaN  Don't go for dinner. They close at 6. Really Y...
# 49700     NaN    NaN   NaN                            Best steak tartare ever
# 49701     NaN    NaN   NaN  Great atmosphere... Live music... Excellent dr...
# 49702     NaN    NaN   NaN                                  Try the Calamari!
# 49703     NaN    NaN   NaN  Just opened today! 45 minutes and still no foo...
# ...       ...    ...   ...                                                ...
# 61686     NaN    NaN   NaN  Love the breakfast sandwiches. Feel they are o...
# 61687     NaN    NaN   NaN  squid ink pasta is a delicacy; this dish is a ...
# 61688     NaN    NaN   NaN                                                  X
# 61689     NaN    NaN   NaN                                 15$ tasting Whoaaa
# 61690     NaN    NaN   NaN  Forgot to ask for no honey so had to down some...
#
#                date  compliment_count count  star  new_star
# 49699  1.318476e+09               0.0  None     1         1
# 49700  1.290986e+09               0.0  None     5         5
# 49701  1.402722e+09               0.0  None     5         5
# 49702  1.318089e+09               0.0  None     4         4
# 49703  1.480997e+09               0.0  None     1         1
# ...             ...               ...   ...   ...       ...
# 61686  1.559182e+09               0.0  None     4         4
# 61687  1.358749e+09               0.0  None     4         4
# 61688  1.279761e+09               0.0  None     1         1
# 61689  1.410655e+09               0.0  None     1         1
# 61690  1.410738e+09               0.0  None     2         2
#
# [11992 rows x 13 columns]
